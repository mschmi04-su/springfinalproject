# %%
#Imports
import requests
import json
import pandas as pd
import pybomb as pb
import pybomb.clients.base_client as baseclient
import pybomb.clients.games_client as gamesclient
import pybomb.clients.game_client as gc
import numpy as np

# %% [markdown]
# Functions to be defined
# - Search function for each console (~7)
# - Filtering function(rating, studio, genre, etc.) (~2)
# - Developer extraction function (1)
# - Game ID function (1)
# -

# %%
df = pd.read_csv('https://query.data.world/s/ejazjx2jqwjyceqspe77k5ac37hy25')
df
# Out:
#        QueryID  ResponseID                                          QueryName  \
# 0           10          10                                     Counter-Strike
# 1           20          20                              Team Fortress Classic
# 2           30          30                                      Day of Defeat
# 3           40          40                                 Deathmatch Classic
# 4           50          50                          Half-Life: Opposing Force
# 5           60          60                                           Ricochet
# 6           70          70                                          Half-Life
# 7           80          80                     Counter-Strike: Condition Zero
# 8           80          80                     Counter-Strike: Condition Zero
# 9          130         130                              Half-Life: Blue Shift
# 10         220         220                                        Half-Life 2
# ...

# %%
help(pb.response)
# Out:
# Help on module pybomb.response in pybomb:
#
# NAME
#     pybomb.response - The response types and factories for PyBomb
#
# CLASSES
#     Response(builtins.tuple)
#         Response
#
#     class Response(Response)
#      |  An API response
#      |
#      |  Method resolution order:
#      |      Response
#      |      Response
#      |      builtins.tuple
#      |      builtins.object
#      |
#      |  Class methods defined here:
#      |
#      |  from_response_data(response_data) from builtins.type
#      |      Response factory
#      |
#      |      :param response_data: requests.models.Response
#      |      :return: pybomb.clients.Response
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  ----------------------------------------------------------------------
# ...

# %%
#Get the genres!!!!!!
key = '64ce54b0ab6eb483b1964ae7979124f96aa791e5' ##Make this an input or encrypt it
game_client = pb.GameClient(key, default_format = 'json')
game_id = 48754
return_fields = ('id', 'name', 'genre')

response = game_client.fetch(game_id)
print(response.results)
# Out:
# {'aliases': 'Call of Duty: Black Ops 3\r\nCODBLOPS 3\r\nCODBLOPS III', 'api_detail_url': 'https://www.giantbomb.com/api/game/3030-48754/', 'date_added': '2015-02-05 14:04:54', 'date_last_updated': '2017-11-10 19:21:45', 'deck': 'Set 40 years after the events of Black Ops II, the twelfth installment of the Call of Duty series brings advanced robotics and biotic augmentations to the clandestine operations of the Black Ops storyline.', 'description': '<h2>Overview</h2><figure data-ref-id="1300-2745032" data-img-src="https://static.giantbomb.com/uploads/original/18/187968/2745032-no-fly-zone.jpg" data-size="small" data-align="right" data-ratio="0.5625" data-width="3840" data-embed-type="image" style="width: 3840px"><a class="fluid-height" style="padding-bottom:56.3%" href="https://static.giantbomb.com/uploads/original/18/187968/2745032-no-fly-zone.jpg" data-ref-id="1300-2745032"><img alt="No Caption Provided" src="https://static.giantbomb.com/uploads/scale_small/18/187968/2745032-no-fly-
# ...

# %%
#Testing
key = '64ce54b0ab6eb483b1964ae7979124f96aa791e5' ##Make this an input or encrypt it
games_client = pb.GamesClient(key)
response = games_client.quick_search(name='halo', platform=pb.XBOX, sort_by='original_release_date', desc= True)

print(response.results)
def getasDicts():
    #make dicts not list, for some reason this only returns the first game. 
    for i in response.results:
        return(i) 
getasDicts()
#print(response.uri)
#print(response.num_page_results)
#print(response.num_total_results)
# Out:
# [{'aliases': 'H2', 'api_detail_url': 'https://www.giantbomb.com/api/game/3030-7110/', 'date_added': '2008-04-01 15:40:47', 'date_last_updated': '2019-04-23 04:17:11', 'deck': "The sequel to Halo: Combat Evolved continues the epic story of humanity's last and best hope: the super-soldier Master Chief, as he defends Earth from a Covenant invasion and fights to prevent the activation of another Halo ring.", 'description': '<h2>Overview</h2><figure data-align="right" data-img-src="https://static.giantbomb.com/uploads/original/0/6131/218914-1093264465.jpg" data-ref-id="1300-218914" data-size="small" data-ratio="0.75" data-width="1024" data-embed-type="image" style="width: 1024px"><a class="fluid-height" style="padding-bottom:75.0%" href="https://static.giantbomb.com/uploads/original/0/6131/218914-1093264465.jpg" data-ref-id="1300-218914"><img alt="No Caption Provided" src="https://static.giantbomb.com/uploads/scale_small/0/6131/218914-1093264465.jpg" srcset="https://static.giantbomb.com/u
# ...

# %%
#Testing

# %%
#Function Definitions

# %%
#Final Code
